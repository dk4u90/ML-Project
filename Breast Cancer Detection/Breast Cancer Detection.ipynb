# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_breast_cancer
cancer_dataset = load_breast_cancer()
type(cancer_dataset)
# Out:
# sklearn.utils.Bunch

# %%
print(cancer_dataset['filename'])
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\sklearn\datasets\data\breast_cancer.csv

# %%
cancer_df = pd.DataFrame(np.c_[cancer_dataset['data'],cancer_dataset['target']], columns=np.append(cancer_dataset['feature_names'],['target']))

# %%
cancer_df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
cancer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
# mean radius                569 non-null float64
# mean texture               569 non-null float64
# mean perimeter             569 non-null float64
# mean area                  569 non-null float64
# mean smoothness            569 non-null float64
# mean compactness           569 non-null float64
# mean concavity             569 non-null float64
# mean concave points        569 non-null float64
# mean symmetry              569 non-null float64
# mean fractal dimension     569 non-null float64
# radius error               569 non-null float64
# texture error              569 non-null float64
# perimeter error            569 non-null float64
# area error                 569 non-null float64
# smoothness error           569 non-null float64
# compactness error          569 non-null float64
# concavity error            569 non-null float64
# ...

# %%
cancer_df.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
plt.figure(figsize=(16,9))
sns.heatmap(cancer_df)

# %%
#sns.pairplot(cancer_df,hue='target')

# %%
plt.figure(figsize=(16,16))
sns.heatmap(cancer_df.corr(),annot=True,cmap='coolwarm',linewidths=2)

# %%
# create second DataFrame by droping target
cancer_df2 = cancer_df.drop(['target'],axis=1)
cancer_df2.shape
# Out:
# (569, 30)

# %%
# visualize correlation barplot
plt.figure(figsize=(16,5))
ax = sns.barplot(cancer_df2.corrwith(cancer_df.target).index,cancer_df2.corrwith(cancer_df.target))
ax.tick_params(labelrotation = 60)

# %%
# input variable
x=cancer_df.drop(['target'], axis=1)
# output variable
y=cancer_df['target']

# %%
# split dataset into train and test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=5)

# %%
# Feature scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train_sc = sc.fit_transform(x_train)
x_test_sc = sc.fit_transform(x_test)

# %%
#Breast Cancer Detection Machine Learning Model Building
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
#Support Vector Classifier
from sklearn.svm import SVC
svc_clasifier = SVC()
svc_clasifier.fit(x_train,y_train)
y_pred_scv = svc_clasifier.predict(x_test)
accuracy_score(y_test,y_pred_scv)
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.5789473684210527

# %%
svc_clasifier2 =SVC()
svc_clasifier2.fit(x_train_sc,y_train)
y_pred_scv_sc = svc_clasifier2.predict(x_test_sc)
accuracy_score(y_test,y_pred_scv_sc)
# Out:
# 0.9473684210526315

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression
lr_classifier = LogisticRegression()
lr_classifier.fit(x_train, y_train)
y_pred_lr = lr_classifier.predict(x_test)
accuracy_score(y_test, y_pred_lr)
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.9736842105263158

# %%
lr_calisifier2 = LogisticRegression()
lr_calisifier2.fit(x_train_sc,y_train)
y_pred_lr_sc = lr_calisifier2.predict(x_test_sc)
accuracy_score(y_test,y_pred_lr_sc)
# Out:
# 0.9736842105263158

# %%
# K – Nearest Neighbor Classifier
from sklearn.neighbors import KNeighborsClassifier
kc_classifier = KNeighborsClassifier()
kc_classifier.fit(x_train,y_train)
y_predict_kc = kc_classifier.predict(x_test)
accuracy_score(y_test,y_predict_kc)
# Out:
# 0.9385964912280702

# %%
kc_classifier2 = KNeighborsClassifier()
kc_classifier2.fit(x_train_sc,y_train)
y_predict_kc_sc = kc_classifier2.predict(x_test_sc)
accuracy_score(y_test,y_predict_kc_sc)
# Out:
# 0.956140350877193

# %%
# Naive Bayes Classifier
from sklearn.naive_bayes import GaussianNB
nb_classifier = GaussianNB()
nb_classifier.fit(x_train,y_train)
y_pred_nb = nb_classifier.predict(x_test)
accuracy_score(y_test,y_pred_nb)
# Out:
# 0.9473684210526315

# %%
nb_classifier2 = GaussianNB()
nb_classifier2.fit(x_train_sc,y_train)
y_pred_nb_sc = nb_classifier2.predict(x_test_sc)
accuracy_score(y_test,y_pred_nb_sc)
# Out:
# 0.9473684210526315

# %%
#Confusion Matrix
cm = confusion_matrix(y_test,y_pred_nb)
sns.heatmap(cm,annot=True)

# %%
#Classification Report of Model
print(classification_report(y_test, y_pred_nb))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.92      0.94        48
#          1.0       0.94      0.97      0.96        66
#
#    micro avg       0.95      0.95      0.95       114
#    macro avg       0.95      0.94      0.95       114
# weighted avg       0.95      0.95      0.95       114

# %%
## Pickle
import pickle
 
# save model
pickle.dump(nb_classifier, open('breast_cancer_detector.pickle', 'wb'))
 
# load model
breast_cancer_detector_model = pickle.load(open('breast_cancer_detector.pickle', 'rb'))
 
# predict the output
y_pred = breast_cancer_detector_model.predict(x_test)
 
# confusion matrix
print('Confusion matrix of GaussianNB model: \n',confusion_matrix(y_test, y_pred),'\n')
 
# show the accuracy
print('Accuracy of GaussianNB model = ',accuracy_score(y_test, y_pred))
# Out:
# ('Confusion matrix of GaussianNB model: \n', array([[44,  4],
#        [ 2, 64]], dtype=int64), '\n')
# ('Accuracy of GaussianNB model = ', 0.9473684210526315)
